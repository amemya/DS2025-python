# %% [markdown]
# # 課題1：平均算出プログラムの作成

# %%
kadai1 = int(input())
kadai2 = int(input())
kadai3 = int(input())

### 以下からプログラムを作成していく
# Out:
# 1
# 2
# 3

# %% [markdown]
# ### 課題1のプログラムについての説明：
#
# - どのような手順で動くプログラムなのか
# - 工夫した点などがあれば

# %% [markdown]
# # 課題2: 分散・標準偏差を求めるプログラムを作成せよ

# %%
kadai1 = int(input())
kadai2 = int(input())
kadai3 = int(input())

### 以下からプログラムを作成していく
# Out:
# 1
# 2
# 3

# %% [markdown]
# ### 課題2のプログラムについての説明：
#
# - どのような手順で動くプログラムなのか
# - 工夫した点などがあれば

# %% [markdown]
# # 発展課題: 入力値の検証

# %%
# ...
