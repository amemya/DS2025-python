# %% [markdown]
# # if文 練習問題（問題文＋回答欄付き）
#
# - 全20題。**必ず `input()` を使う**こと。
# - 難易度は徐々に上がります。12〜16は発展、17〜19は挑戦です。
# - 必要に応じて `and / or / not` や 連鎖比較（`0 <= x <= 10`）を活用しましょう。

# %% [markdown]
# ### 問題1：正の数・負の数・0を判定しよう
# キーボードから数値を1つ入力し、**正の数／負の数／0** のいずれかを出力してください。

# %%
x = float(input("数値を入力してください: "))
# ここから if 文で判定

# %% [markdown]
# ### 問題2：偶数か奇数かを判定しよう
# 整数を1つ入力し、**偶数** か **奇数** かを出力してください。

# %%
n = int(input("整数を入力してください: "))
# ここから if 文で判定

# %% [markdown]
# ### 問題3：テストの合否を判定しよう
# テストの点数を入力し、**60点以上なら「合格」**、それ以外は「不合格」と出力してください。

# %%
score = int(input("点数を入力してください: "))
# ここから if 文で判定

# %% [markdown]
# ### 問題4：BMIで健康状態を分類しよう
#
# 身長(cm)と体重(kg)を入力し、BMI = 体重 ÷ (身長[m]^2) を計算して次の基準で表示してください。
#
# - 18.5未満：やせ気味
# - 18.5〜25未満：標準体重
# - 25以上：肥満気味

# %%
h = float(input("身長(cm): "))
w = float(input("体重(kg): "))
# ここから if 文で判定

# %% [markdown]
# ### 問題5：入力値のタイプを判定しよう
# 入力した1つの値が **数値**・**文字列**・**その他** のどれかを判定して出力してください。
#
# **ヒント**：
# `str.isdigit()`, `str.isalpha()` を利用できます。

# %%
s = input("値を入力してください: ")
# ここから if 文で判定

# %% [markdown]
# ### 問題6：年齢によって世代を分類しよう
#
# 年齢を入力し、以下の区分を出力してください。
#
# - 13歳未満：子ども
# - 13〜19歳：ティーン
# - 20〜64歳：成人
# - 65歳以上：シニア

# %%
age = int(input("年齢を入力してください: "))
# ここから if 文で判定

# %% [markdown]
# ### 問題7：月の入力が正しいか確認しよう
# 整数を入力し、**有効な月(1-12)**か**無効な月**かを出力してください。

# %%
month = int(input("月(1-12): "))
# ここから if 文で判定

# %% [markdown]
# ### 問題8：3の倍数を判定しよう
# 整数を入力し、3の倍数なら「3の倍数です」、そうでなければ「3の倍数ではありません」と出力してください。

# %%
n = int(input("整数を入力してください: "))
# ここから if 文で判定

# %% [markdown]
# ### 問題9：2つの数の大小を比較しよう
# 2つの数を入力し、「1つ目が大きい／2つ目が大きい／同じ大きさ」のいずれかを出力してください。

# %%
a = float(input("1つ目の数: "))
b = float(input("2つ目の数: "))
# ここから if 文で判定

# %% [markdown]
# ### 問題10：データの外れ値を検出しよう
# 平均50・標準偏差10とし、入力した値が 平均±2*{標準偏差}の範囲なら「正常」、それ以外は「外れ値」と出力してください。

# %%
x = float(input("データ値を入力: "))
mean, sd = 50, 10
# ここから if 文で判定

# %% [markdown]
# ### 問題11：気温からコメントを出そう
#
# 気温(℃)を入力し、次のルールでコメントを出力してください。
#
# - 0未満：氷点下です
# - 0〜15未満：肌寒いです
# - 15〜25未満：過ごしやすいです
# - 25以上：暑い日です

# %%
t = float(input("気温(℃): "))
# ここから if 文で判定

# %% [markdown]
# ### 問題12：3つの値の中央値を求めよう
# 3つの数値を入力し、真ん中の値（中央値）を出力してください。
#
# **ヒント**：
# `a ≤ b ≤ c` などの関係を if で列挙します。

# %%
a = float(input("1つ目の値: "))
b = float(input("2つ目の値: "))
c = float(input("3つ目の値: "))
# ここから if 文で判定（中央値）

# %% [markdown]
# ### 問題13：x, y の符号から位置を判定しよう
#
# x座標とy座標を入力し、以下のどれかを出力してください。
#
# - 第1象限 (x>0, y>0)
# - 第2象限 (x<0, y>0)
# - 第3象限 (x<0, y<0)
# - 第4象限 (x>0, y<0)
# - 軸上です (x==0 or y==0)

# %%
x = float(input("x座標: "))
y = float(input("y座標: "))
# ここから if 文で判定

# %% [markdown]
# ### 問題14：簡易FizzBuzz
# 整数を1つ入力し、3の倍数なら『Fizz』、5の倍数なら『Buzz』、両方の倍数なら『FizzBuzz』と出力してください。

# %%
n = int(input("整数を入力してください: "))
# ここから if 文で判定（3,5,両方）

# %% [markdown]
# ### 問題15：素数判定（1〜10の範囲）
# 1〜10の整数を入力し、それが素数なら『素数です』、それ以外は『素数ではありません』と出力してください。
#
# **ヒント**：
# 素数は 2, 3, 5, 7 です。

# %%
n = int(input("1〜10の整数を入力: "))
# ここから if 文で判定

# %% [markdown]
# ### 問題16：1回だけコラッツ予想
# 正の整数 n を入力し、偶数なら `n/2`、奇数なら `3n+1` を出力してください。

# %%
n = int(input("正の整数 n: "))
# ここから if 文で分岐

# %% [markdown]
# ### 問題17：3つの値の最大値を求めよう（max関数禁止）
# 3つの数を入力し、**if文のみ**で最大値を求めて出力してください。`max()` は禁止です。

# %%
a = float(input("1つ目の値: "))
b = float(input("2つ目の値: "))
c = float(input("3つ目の値: "))
# ここから if 文のみで最大値を決定

# %% [markdown]
# ### 問題18：整数の符号と桁数を総合判定しよう
# 整数を入力し、『正の数/負の数/0』と『1桁/2桁/3桁以上』をそれぞれ出力してください。

# %%
s = input("整数を入力してください（符号付き可）: ")
# ここから if 文で判定（符号と桁数）

# %% [markdown]
# ### 問題19：成績を総合評価しよう
#
# 国語・数学・英語の点数（0〜100）を入力し、次で評価を出力してください。
#
# - すべて80点以上：A（優秀）
# - いずれかが80点以上 かつ すべて50点以上：B（良好）
# - 1科目でも50点未満があるが、全体平均が50以上：C（平均）
# - 全体平均が50未満：D（要努力）

# %%
jp = int(input("国語: "))
ma = int(input("数学: "))
en = int(input("英語: "))
avg = (jp + ma + en) / 3
# ここから if 文で評価を決定
