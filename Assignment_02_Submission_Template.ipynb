# %% [markdown]
# # 課題2
#
# ## 2-1 自作問題作成
#
# 以下にあなたが考えたfor, while, リストを使って解く問題を作成してください。
# また、その問題を解くプログラム・解説を作成してください。
#
# - 最低1問、最大で3問まで作成してください（2つ以上作る場合、欄を増やして作ってください）。
# - 入力例と出力例は**2~4つ**含めてください。
# - 問題・解答の記述の仕方は**「for, while, リスト演習問題」の最初の問題（A0）**を参考にしてください。
# - 数式をかっこよく表したい人は「markdown TeX {表したい記号の名前}」と検索すると良いかもしれません。
# - 良い問題は今後の授業で紹介したり、使うかもしれません。
#
# ※ 作った問題を誰かに解いてもらってから提出すると良いと思います。解いた人はフィードバックしてあげてください。
#
# - **評価基準**：
#     - 問題として抜けなく成立しているか？（難しければよいわけではないです）。
#     - 入力形式と出力形式が一致しているか？
#     - 自分で作った問題を解けているか？
#     - 独創性（加点ポイント）

# %% [markdown]
# # 2-1 自作問題作成欄
#
# 以下に「問題」「解答」「解説」を記述してください。

# %% [markdown]
# # あなたの問題のタイトル
#
#
# ## 問題文
#
# 問題文を入力
#
# ## 制約
#
# ```
# 制約を入力
# ```
#
# ## 入力形式
#
# ```
#
# ここに入力の形式
#
# ```
#
# ## 出力形式
#
# ```
# ここに出力形式
# ```
#
# ## 入力例1
#
# ```
# 入力例1
# ```
#
# ## 出力例1
#
# ```
# 出力例1
# ```
#
# ## 入力例2
#
# ```
# 入力例2
# ```
#
# ## 出力例2
#
# ```
# 出力例2
# ```
#
# ## 入力例3
#
# ```
# 入力例3
# ```
#
# ## 出力例3
#
# ```
# 出力例3
# ```

# %% [markdown]
# ## 自作問題の解答
#
# どのように考えて解くのか、解説をここに記述

# %%
# 自作問題を解くプログラムを以下に記述

# %% [markdown]
# ## 発展課題: 演習問題
#
# 以下に、演習問題の解答を提出してください。
#
# 正しく解けていて、説明もできている場合、
#
# - A1, A2: 3点
# - B1:5点
# - C1:7点
#
# として課題全体を加点します（満点は100点になります）。
#
# 自分の作ったプログラムについて、必ず自分の言葉で説明を記述してください。

# %% [markdown]
# # 解答

# %%
#A1のプログラムを以下に貼り付け

# %% [markdown]
# A1の課題1のプログラムについての説明：
#
# どのような手順で動くプログラムなのか、工夫した点など

# %%
#A2のプログラムを以下に貼り付け

# %% [markdown]
# A2の課題1のプログラムについての説明：
#
# どのような手順で動くプログラムなのか、工夫した点など

# %%
#B1のプログラムを以下に貼り付け

# %% [markdown]
# B1の課題1のプログラムについての説明：
#
# どのような手順で動くプログラムなのか、工夫した点など

# %%
#C1のプログラムを以下に貼り付け

# %% [markdown]
# C1の課題1のプログラムについての説明：
#
# どのような手順で動くプログラムなのか、工夫した点など
